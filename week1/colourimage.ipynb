# %%
import cv2
from matplotlib import pyplot as plt
image = cv2.imread(r"D:\AP22110010458\digital-image-preprocessing\assets\photo.jpg")
if image is None:
    print("Error: Could not load the image. Check the file path.")
else:
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(8, 6))
    plt.imshow(image_rgb)
    plt.axis('off')
    plt.title("Color Image")
    plt.show()
    cv2.imwrite("output_image.png", image)
    cv2.imwrite("output_image.bmp", image)
    print("Image has been saved in PNG and BMP formats.")
# Out:
# Image has been saved in PNG and BMP formats.
